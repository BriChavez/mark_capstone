# %%
import json
import re
import os
import string
from numpy.random import choice
import random
# import nltk
import re
import sys
import PyPDF2
import os
# from nltk.corpus import wordnet
# from numpy.random import choice
# from nltk.tokenize import sent_tokenize, word_tokenize
# from nltk.corpus import stopwords
# from nltk.stem import PorterStemmer
# from nltk.tokenize import PunktSentenceTokenizer
# nltk.download('wordnet')
# from nltk.stem import WordNetLemmatizer


with open('data/bri/data_stack_resumes.txt', 'r') as resume_script:
    # open txt file and read to string, string to lower
    resume_file = resume_script.read()
    resume_file = resume_file.lower()



# print(resume_file)

# %%
import language_tool_python
import re
import string
import random
import re
import os
from numpy.random import choice


"""SET RESUME JOB TYPE YOU WOULD LIKE TO ACCESS"""
# set variable to begin
# job_type = 'CONSTRUCTION'
# # set the folder path using our job type variable
# folder_path = f'data/Resume/{job_type}'
# # extract resume folder name, which is what our resume file is named for
# resume_folder = os.path.basename(folder_path).lower()

# %%
from textblob.en import Spelling
import re

# textToLower = ""

# with open("originOfSpecies.txt", "r") as f1:          
# 	text = f1.read()
# 	# Lower all the capital letters
# 	textToLower = text.lower()

# # Find all the words and place them into a list
# words = re.findall("[a-z]+", textToLower)
# Join them into one string
# oneString = " ".join(resume_string)

# # The path we want to store our stats file at
# pathToFile = "train.txt"
# # Connect the path to the Spelling object
# spelling = Spelling(path=pathToFile)
# spelling.train(oneString, pathToFile)

# %%
import language_tool_python
from textblob.en import Spelling
from textblob import TextBlob

pathToFile = "train.txt"
spelling = Spelling(path=pathToFile)
text = " "

with open("finished_resumes/generated_construction_resumes.txt", "r") as f:
	text = f.read()

words = re.findall(r"[A-Za-z]+|[.,]", text)
corrected = " "
for i in words:
    # Spell checking word by word
    corrected = corrected + " " + spelling.suggest(i)[0][0]



tool = language_tool_python.LanguageTool('en-US')
checked_text = tool.correct(corrected)
print(type(checked_text))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_13702/1850730418.py in <module>
#       1 import language_tool_python
# ----> 2 from textblob.en import Spelling
#       3 from textblob import TextBlob
#       4
#       5 pathToFile = "train.txt"
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# dropped_words = [w for w in resume_string if w in stop_words]
# no_nonsense_resume = [idx for idx in stop_dropped_resume if not re.findall("[^\u0000-\u05C0\u2100-\u214F]+", idx)]
# no_nonsense_resume = ' '.join(char for char in resume_string if not char.isalnum() or char in punctuation)

# resume_string = re.findall(r"[A-Za-z]+|[.,]", resume_file)


more_drops = ['state', 'city', 'name', 'company', 'college', 'university']
stop_dropped_resume = [w for w in resume_string if not w in more_drops]

# # encode the string into ‘ASCII’ and error as ‘ignore’ to remove Unicode characters
# no_nonsense = str.encode(str(resume_string), "utf-8", "ignore")
# # # # decode the string back in its form
# no_nonsense_resume = no_nonsense.decode()

print(stop_dropped_resume[:1000])
# Out:
# ['to', 'arun', 'thomas', 'and', 'the', 'team', 'at', 'all', 'star', 'directories', 'hello', 'writing', 'to', 'apply', 'for', 'the', 'data', 'engineering', 'internship', 'at', 'all', 'star', 'directories', 'am', 'current', 'student', 'and', 'career', 'changer', 'moving', 'from', 'the', 'commerce', 'customer', 'service', 'industry', 'into', 'the', 'tech', 'field', 'am', 'thrilled', 'at', 'the', 'prospect', 'of', 'joining', 'the', 'team', 'at', 'asd', 'and', 'know', 'that', 'could', 'bring', 'something', 'great', 'to', 'the', 'after', 'graduating', 'from', 'my', 'initial', 'professional', 'experience', 'was', 'in', 'the', 'commerce', 'industry', 'including', 'two', 'years', 'working', 'for', 'the', 'exercise', 'apparel', 'start', 'up', 'nuu', 'muu', 'as', 'the', 'office', 'manager', 'there', 'got', 'incredibly', 'familiar', 'with', 'the', 'front', 'end', 'user', 'facing', 'side', 'of', 'the', 'including', 'some', 'basic', 'website', 'maintenance', 'and', 'maintaining', 'the', 'inventory',

# %%
# remove all but letter . and spaces
article_text = re.sub(r'[^A-Za-z. ]', '', article_text)

# %%
tokenized_doc = word_tokenize(stop_dropped_resume)
tagged_sents = nltk.pos_tag(tokenized_doc)
NE = nltk.ne_chunk(tagged_sents)

named_ents = []
for tagged_tree in NE:
    print(tagged_tree)
    if hasattr(tagged_tree, 'label'):
        entity_name = ' '.join(c[0] for c in tagged_tree.leaves())
        entity_type = tagged_tree.label()
        named_ents.append((entity_name, entity_type))
    else:
        pass
    print(named_ents)

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk import Tree


def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(
                " ".join([token for token, pos in subtree.leaves()]))
        if current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk
# Out:
# [<generator object <genexpr> at 0x7fc80f3b7450>]

# %%
with open('data/bri/data_stack_resumes.txt', 'r') as resume_script:
    # open txt file and read to string, string to lower
    resume_file = resume_script.read()
    resume_file = resume_file.lower()

# resume_string = re.findall(r"[A-Za-z]+|[.,]", resume_file)
# resume_string = re.findall(r"[?:\w+[']?\w]+|[A-Za-z]+|[.,]", resume_file)
resume_addition = re.findall(r"(?:\w+[']?\w)", resume_file)

print(resume_addition)
# more_drops = ['state', 'city', 'name', 'company',
#               'college', 'am', 'the', 'to', 'in']
# stop_dropped_resume = [w for w in resume_string if not w in more_drops]


# stop_dropped_resume = str(stop_dropped_resume)
# print(stop_dropped_resume)

# %%
# for loop that runs over every word in test
# no_nonsense_resume = " ".join(no_nonsense_resume)
# resume_string = re.findall(r"[\w']+|[.,!?;]", no_nonsense_resume)
# resume_string = re.sub('['+string.punctuation+']', '', str(no_nonsense_resume)).split()
# resume_string = no_nonsense_resume
# re.sub(r"", "", line.strip())
import json
resume_dict = {}

for i, word in enumerate(stop_dropped_resume[:-1]):
    this_word = stop_dropped_resume[i+1]
    # if this_word is in dict, asssign it to 'next_count'
    if this_word not in resume_dict:
        next_count = {}
        resume_dict[this_word] = next_count

    # if not, create empty dictionary with this_word as the key and next_count as the value
    else:
        next_count = resume_dict[this_word]

    if word in next_count:
        next_count[word] += 1
    else:
        next_count[word] = 1
this_word = stop_dropped_resume[i+1]

print(json.dumps(resume_dict, sort_keys=True, indent=3))

# %%
"""start the story"""

# name variable with the first word in our list of words
# first_word = random.choice(resume_string)
# print(first_word)
# name the first word of our story as

first_word = random.choice(resume_string)
while first_word in string.punctuation:
    first_word = random.choice(resume_string)
print(first_word)

story = []


def start_story(str):
    """function to start the story"""
    if story == []:
        # set story up with a first word
        story.append(first_word)
    else:
        # dont start the story if its already been started
        pass
    return story


start_story(resume_string)
# call function on our list of words from the text
# Out:
# laws
# ['laws']

# %%
def whos_next():
    """function to get the next word using weighted probability"""
    current_word = story[-1]
    for outer_word, inner_dict in resume_dict.items():
        # pick out our nested dict for specific word
        word_self_total = inner_dict.items()
        # get the next words and instances
        total_occurances = inner_dict.values()
        # seperate the instances
        if outer_word == current_word:
            # pull the dictionary for the current word
            total = sum(total_occurances)
            # add the total times a word followed current word
            probs = []
            # set empty variable for the percent chance of each word occuring
            hopefuls = []
            # set a list of all words that came after current word
            likely = []
            # set an empty list to grab the count of each word
            for number in total_occurances:
                # pull every number of times each word came after current
                percent = number / total
                # factor the percent chance of a word being next
                probs.append(percent)
                # add each percent to our probs list

            for word, num in word_self_total:
                # pull words and their values from our inner dict
                hopefuls.append(word)
                # add each word to our hopefuls list
                likely.append(num)
                # add each number to our likely list
                global rng_says

            rng_says = choice(hopefuls, p=probs)
            # weighted rng based off the percent probability of word occuring
            # return rng_says

            next_word = str(rng_says)
            # change rng output from numpy to string
            story.append(next_word)
            # add our next word string to the story
            # current_word = story[-1]
            # set current word to be the last word of the story

# %%
"""add words to the story"""



while len(story) < 500:
    whos_next()

whole_story = ' '.join(story)

# this drops the white spaces before punctuation
whole_story = re.sub(r'\s([?.,!](?:\s|$))', r'\1', whole_story)
# print(whole_story)

# %%
# split the text, on sentences this time
sentences = re.split('[?.]', whole_story)
# start an empty list
cap_sent = []
# for loop to run through every sentence in our story
for sentence in sentences:
    # capitalize the first word of 
    cap_sent.append((sentence.lstrip().capitalize() + '.'))
cap_sent = ' '.join(cap_sent)

# nlp = spacy.load("en_core_web_sm")

# text = sentences
# doc_dep = nlp(text)
# for i in range(len(doc_dep)):
#     token = doc_dep[i]
#     if token.tag_ in ['VBP', 'VBZ']:
#         print(token.text, token.lemma_, token.pos_, token.tag_)
#         text = text.replace(token.text, token._.inflect("VBD"))
# print(cap_sent)

# %%
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(cap_sent)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.morph)
sentence_spans = list(doc.sents)
displacy.serve(sentence_spans, style="dep")
# Out:
# Laws law NOUN NNS nsubj Xxxx Number=Plur
# applicable applicable ADJ JJ ROOT xxxx Degree=Pos
# many many ADJ JJ nsubj xxxx Degree=Pos
# overcame overcome VERB VBD ccomp xxxx Tense=Past|VerbForm=Fin
# we we PRON PRP dobj xx Case=Nom|Number=Plur|Person=1|PronType=Prs
# and and CCONJ CC cc xxx ConjType=Cmp
# welding welding NOUN NN conj xxxx Number=Sing
# with with ADP IN prep xxxx
# meetings meeting NOUN NNS pobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# vendors vendor NOUN NNS conj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# aerial aerial NOUN NN conj xxxx Number=Sing
# of of ADP IN prep xx
# knowledge knowledge NOUN NN compound xxxx Number=Sing
# gain gain NOUN NN pobj xxxx Number=Sing
# to to PART TO prep xx
# , , PUNCT , punct , PunctType=Comm
# project project VERB VB dep xxxx VerbForm=Inf
# the the DET DT det xxx Definite=Def|PronType=Art
# managed manage VERB VBN amod xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# surveyors surveyor NOUN NNS dobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# education education NOUN NN nmod xxxx Number=Sing
# extensive extensive ADJ JJ amod xxxx Degree=Pos
# systems system NOUN NNS compound xxxx Number=Plur
# keeping keeping NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# products product NOUN NNS conj xxxx Number=Plur
# of of ADP IN prep xx
# university university NOUN NN compound xxxx Number=Sing
# state state NOUN NN nmod xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# city city NOUN NN conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# eia eia NOUN NN conj xxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# design design NOUN NN pobj xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Weather weather NOUN NN ROOT Xxxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# function function VERB VB conj xxxx VerbForm=Inf
# to to ADP IN prep xx
# . . PUNCT . punct . PunctType=Peri
# Equipment equipment NOUN NN nmod Xxxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# monitored monitor VERB VBD amod xxxx Tense=Past|VerbForm=Fin
# contracts contract NOUN NNS conj xxxx Number=Plur
# negotiating negotiating NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# development development NOUN NN conj xxxx Number=Sing
# project project NOUN NN nsubj xxxx Number=Sing
# with with ADP IN prep xxxx
# compliance compliance NOUN NN pobj xxxx Number=Sing
# in in ADP IN prep xx
# ksu ksu PROPN NNP pobj xxx Number=Sing
# via via ADP IN prep xxx
# hazards hazard NOUN NNS pobj xxxx Number=Plur
# all all PRON DT appos xxx
# for for ADP IN prep xxx
# programs program NOUN NNS pobj xxxx Number=Plur
# scada scada PROPN NNP appos xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# used use VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# effectively effectively ADV RB advmod xxxx
# to to AUX IN aux xx
# surveyors surveyor NOUN NNS xcomp xxxx Number=Plur
# quantity quantity NOUN NN compound xxxx Number=Sing
# item item NOUN NN npadvmod xxxx Number=Sing
# specific specific ADJ JJ amod xxxx Degree=Pos
# suggesting suggesting NOUN NN dobj xxxx Number=Sing
# by by ADP IN prep xx
# profit profit NOUN NN pobj xxxx Number=Sing
# increased increase VERB VBN conj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# faxes fax NOUN NNS nsubj xxxx Number=Plur
# receiving receive VERB VBG conj xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# supervise supervise VERB VB conj xxxx VerbForm=Inf
# responsibilities responsibility NOUN NNS dobj xxxx Number=Plur
# . . PUNCT . punct . PunctType=Peri
# Station station NOUN NN nsubj Xxxxx Number=Sing
# fueling fuel VERB VBG csubj xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# gas gas NOUN NN nmod xxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# site site NOUN NN conj xxxx Number=Sing
# job job NOUN NN compound xxx Number=Sing
# current current ADJ JJ dobj xxxx Degree=Pos
# to to ADP IN prep xx
# responses response NOUN NNS pobj xxxx Number=Plur
# written write VERB VBN acl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# excellent excellent ADJ JJ amod xxxx Degree=Pos
# skills skill NOUN NNS dobj xxxx Number=Plur
# my my PRON PRP$ poss xx Number=Sing|Person=1|Poss=Yes|PronType=Prs
# serve serve NOUN NN dobj xxxx Number=Sing
# to to PART TO aux xx
# adherence adherence VERB VB acl xxxx VerbForm=Inf
# ensure ensure VERB VB ROOT xxxx VerbForm=Inf
# to to PART TO aux xx
# aptitude aptitude VERB VB xcomp xxxx VerbForm=Inf
# mathematical mathematical ADJ JJ advmod xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# platforms platform VERB VBZ conj xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# media medium NOUN NNS dobj xxxx Number=Plur
# social social ADJ JJ acomp xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# volume volume NOUN NN compound xxxx Number=Sing
# traffic traffic NOUN NN nmod xxxx Number=Sing
# the the PRON DT appos xxx Definite=Def|PronType=Art
# with with ADP IN prep xxxx
# tasked tasked ADJ JJ amod xxxx Degree=Pos
# official official ADJ JJ amod xxxx Degree=Pos
# reporting report VERB VBG acl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# expense expense NOUN NN compound xxxx Number=Sing
# supply supply NOUN NN dobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# codes code NOUN NNS conj xxxx Number=Plur
# safety safety NOUN NN compound xxxx Number=Sing
# construction construction NOUN NN compound xxxx Number=Sing
# oversee oversee NOUN NN pobj xxxx Number=Sing
# to to ADP IN prep xx
# , , PUNCT , punct , PunctType=Comm
# of of ADP IN prep xx
# reduction reduction NOUN NN pobj xxxx Number=Sing
# after after ADP IN prep xxxx
# state state NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# support support NOUN NN compound xxxx Number=Sing
# management management NOUN NN compound xxxx Number=Sing
# project project NOUN NN conj xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# managed manage VERB VBN nsubj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# all all PRON DT dep xxx
# trained train VERB VBN relcl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# moved move VERB VBN conj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# supervision supervision NOUN NN conj xxxx Number=Sing
# direct direct ADJ JJ amod xxxx Degree=Pos
# professional professional ADJ JJ amod xxxx Degree=Pos
# exercise exercise NOUN NN compound xxxx Number=Sing
# field field NOUN NN compound xxxx Number=Sing
# construction construction NOUN NN compound xxxx Number=Sing
# store store NOUN NN dep xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# in in ADP IN nmod xx
# expert expert PROPN NNP pobj xxxx Number=Sing
# suite suite PROPN NNP compound xxxx Number=Sing
# office office PROPN NNP dobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# pa pa PROPN NNP npadvmod xx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Scheduling scheduling NOUN NN compound Xxxxx Number=Sing
# project project NOUN NN compound xxxx Number=Sing
# road road NOUN NN compound xxxx Number=Sing
# eldams eldam NOUN NNS nsubj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# strategy strategy NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# developed develop VERB VBD conj xxxx Tense=Past|VerbForm=Fin
# were be AUX VBD ROOT xxxx Mood=Ind|Tense=Past|VerbForm=Fin
# documents document NOUN NNS compound xxxx Number=Plur
# loan loan NOUN NN attr xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# s. s. PROPN NNP compound x. Number=Sing
# Manner Manner PROPN NNP appos Xxxxx Number=Sing
# timely timely ADV RB advmod xxxx
# in in ADP IN prep xx
# alert alert NOUN NN pobj xxxx Number=Sing
# must must AUX MD aux xxxx VerbForm=Fin
# insurance insurance NOUN NN dep xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# topsides topside VERB VBZ conj xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# whj whj PROPN NNP compound xxx Number=Sing
# bh bh PROPN NNP compound xx Number=Sing
# total total NOUN NN dobj xxxx Number=Sing
# for for ADP IN prep xxx
# responsible responsible ADJ JJ amod xxxx Degree=Pos
# . . PUNCT . punct . PunctType=Peri
# Skills skill NOUN NNS compound Xxxxx Number=Plur
# maintenance maintenance NOUN NN compound xxxx Number=Sing
# operation operation NOUN NN compound xxxx Number=Sing
# equipment equipment NOUN NN ROOT xxxx Number=Sing
# or or CCONJ CC cc xx ConjType=Cmp
# new new ADJ JJ amod xxx Degree=Pos
# framed framed ADJ JJ conj xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# materials material NOUN NNS conj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# installed instal VERB VBD conj xxxx Tense=Past|VerbForm=Fin
# properly properly ADV RB advmod xxxx
# purchases purchase NOUN NNS dobj xxxx Number=Plur
# for for ADP IN prep xxx
# procedures procedure NOUN NNS pobj xxxx Number=Plur
# developed develop VERB VBN acl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Levels level NOUN NNS ROOT Xxxxx Number=Plur
# high high ADJ JJ amod xxxx Degree=Pos
# education education NOUN NN appos xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Specifications specification NOUN NNS nsubj Xxxxx Number=Plur
# approved approve VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# the the PRON DT dobj xxx Definite=Def|PronType=Art
# of of ADP IN prep xx
# implementation implementation NOUN NN compound xxxx Number=Sing
# pavement pavement NOUN NN pobj xxxx Number=Sing
# the the PRON DT dobj xxx Definite=Def|PronType=Art
# for for ADP IN prep xxx
# operation operation NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# supervision supervision NOUN NN compound xxxx Number=Sing
# subcontractor subcontractor NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# delivery delivery NOUN NN compound xxxx Number=Sing
# commodity commodity NOUN NN compound xxxx Number=Sing
# radioactive radioactive ADJ JJ conj xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# installing instal VERB VBG advcl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# tools tool NOUN NNS compound xxxx Number=Plur
# power power NOUN NN dobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# operator operator NOUN NN compound xxxx Number=Sing
# pads pad NOUN NNS conj xxxx Number=Plur
# of of ADP IN prep xx
# completion completion NOUN NN compound xxxx Number=Sing
# job job NOUN NN pobj xxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# rail rail NOUN NN compound xxxx Number=Sing
# light light NOUN NN compound xxxx Number=Sing
# billion billion NUM CD conj xxxx NumType=Card
# . . PUNCT . punct . PunctType=Peri
# Ee Ee PROPN NNP compound Xx Number=Sing
# dragados dragado NOUN NNS nsubj xxxx Number=Plur
# en en ADP IN prep xx
# iniciales iniciale NOUN NNS pobj xxxx Number=Plur
# favor favor VERB VBP ROOT xxxx Tense=Pres|VerbForm=Fin
# por por NOUN NN compound xxx Number=Sing
# menor menor NOUN NN compound xxxx Number=Sing
# delito delito PROPN NNP dobj xxxx Number=Sing
# un un PROPN NNP compound xx Number=Sing
# incluir incluir PROPN NNP compound xxxx Number=Sing
# puede puede NOUN NN compound xxxx Number=Sing
# proceso proceso NOUN NNS compound xxxx Number=Plur
# del del PROPN NNP compound xxx Number=Sing
# escrito escrito PROPN NNP compound xxxx Number=Sing
# por por PROPN NNP compound xxx Number=Sing
# sellado sellado NOUN NN dobj xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Tasks task NOUN NNS ROOT Xxxxx Number=Plur
# complex complex ADJ JJ amod xxxx Degree=Pos
# through through ADP IN prep xxxx
# weekly weekly ADJ JJ amod xxxx Degree=Pos
# conducted conduct VERB VBN amod xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# march march NOUN NN pobj xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Inspectors inspector NOUN NNS nsubj Xxxxx Number=Plur
# qc qc INTJ UH nsubj xx
# qa qa INTJ UH intj xx
# a a DET DT det x Definite=Ind|PronType=Art
# ensure ensure NOUN NN dobj xxxx Number=Sing
# to to ADP IN prep xx
# materials material NOUN NNS nmod xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# security security NOUN NN conj xxxx Number=Sing
# individuals individual NOUN NNS pobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# contractors contractor NOUN NNS conj xxxx Number=Plur
# all all PRON DT advmod xxx
# for for ADP IN prep xxx
# system system NOUN NN pobj xxxx Number=Sing
# tracking track VERB VBG acl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# production production NOUN NN compound xxxx Number=Sing
# power power NOUN NN compound xxxx Number=Sing
# astoria astoria NOUN NN dobj xxxx Number=Sing
# for for ADP IN prep xxx
# location location NOUN NN nmod xxxx Number=Sing
# regional regional ADJ JJ amod xxxx Degree=Pos
# project project NOUN NN compound xxxx Number=Sing
# history history NOUN NN compound xxxx Number=Sing
# work work NOUN NN compound xxxx Number=Sing
# pavement pavement NOUN NN pobj xxxx Number=Sing
# rigid rigid ADJ JJ advmod xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# receipts receipt VERB VBZ conj xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# cash cash NOUN NN nmod xxxx Number=Sing
# petty petty ADJ JJ amod xxxx Degree=Pos
# office office NOUN NN compound xxxx Number=Sing
# ms ms PROPN NNP dobj xx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# incomplete incomplete ADJ JJ nsubj xxxx Degree=Pos
# is be AUX VBZ ROOT xx Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# safety safety NOUN NN compound xxxx Number=Sing
# construction construction NOUN NN nsubj xxxx Number=Sing
# worksite worksite ADJ JJ ccomp xxxx Degree=Pos
# to to ADP IN prep xx
# january january PROPN NNP compound xxxx Number=Sing
# engineer engineer NOUN NN compound xxxx Number=Sing
# geotechnical geotechnical ADJ JJ pobj xxxx Degree=Pos
# . . PUNCT . punct . PunctType=Peri
# Gravel gravel NOUN NN nmod Xxxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# tools tool VERB VBZ conj xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# prototype prototype NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# private private ADJ JJ conj xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# outreach outreach ADJ JJ conj xxxx Degree=Pos
# maximize maximize NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# standards standard NOUN NNS conj xxxx Number=Plur
# operational operational ADJ JJ amod xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# surveys survey NOUN NNS conj xxxx Number=Plur
# area area NOUN NN compound xxxx Number=Sing
# madison madison PROPN NNP nsubj xxxx Number=Sing
# greater great ADJ JJR amod xxxx Degree=Cmp
# for for ADP IN prep xxx
# arrangements arrangement NOUN NNS pobj xxxx Number=Plur
# travel travel VERB VBP ROOT xxxx Tense=Pres|VerbForm=Fin
# to to ADP IN prep xx
# plans plan NOUN NNS pobj xxxx Number=Plur
# interpret interpret VERB VB advcl xxxx VerbForm=Inf
# and and CCONJ CC cc xxx ConjType=Cmp
# contract contract VERB VB conj xxxx VerbForm=Inf
# the the PRON DT dobj xxx Definite=Def|PronType=Art
# through through ADP IN prep xxxx
# following follow VERB VBG pcomp xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# , , PUNCT , punct , PunctType=Comm
# contractors contractor NOUN NNS conj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# policy policy NOUN NN compound xxxx Number=Sing
# company company NOUN NN conj xxxx Number=Sing
# that that PRON WDT nsubj xxxx PronType=Rel
# ensure ensure VERB VBP relcl xxxx Tense=Pres|VerbForm=Fin
# to to ADP IN prep xx
# october october PROPN NNP compound xxxx Number=Sing
# estimator estimator NOUN NN pobj xxxx Number=Sing
# to to ADP IN prep xx
# responsible responsible ADJ JJ pobj xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# mixed mixed ADJ JJ conj xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# one one NUM CD conj xxx NumType=Card
# and and CCONJ CC cc xxx ConjType=Cmp
# improvements improvement NOUN NNS conj xxxx Number=Plur
# adventureland adventureland NOUN NN advmod xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# locate locate VERB VBP conj xxxx Tense=Pres|VerbForm=Fin
# . . PUNCT . punct . PunctType=Peri
# Engineers engineer NOUN NNS nmod Xxxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# invoices invoice NOUN NNS conj xxxx Number=Plur
# vendor vendor NOUN NN ROOT xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# tasks task NOUN NNS nsubj xxxx Number=Plur
# keep keep VERB VBP conj xxxx Tense=Pres|VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# communication communication NOUN NN conj xxxx Number=Sing
# strong strong ADJ JJ amod xxxx Degree=Pos
# demonstrated demonstrate VERB VBD ccomp xxxx Tense=Past|VerbForm=Fin
# . . PUNCT . punct . PunctType=Peri
# Sites site NOUN NNS compound Xxxxx Number=Plur
# project project NOUN NN compound xxxx Number=Sing
# functional functional ADJ JJ amod xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# city city NOUN NN compound xxxx Number=Sing
# pad pad NOUN NN compound xxx Number=Sing
# final final ADJ JJ ROOT xxxx Degree=Pos
# during during ADP IN prep xxxx
# warehouse warehouse NOUN NN pobj xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# led lead VERB VBN amod xxx Aspect=Perf|Tense=Past|VerbForm=Part
# hospital hospital NOUN NN compound xxxx Number=Sing
# orthopedic orthopedic NOUN NN dobj xxxx Number=Sing
# the the PRON DT nsubj xxx Definite=Def|PronType=Art
# of of ADP IN prep xx
# out out ADP RP pobj xxx
# print print NOUN NN compound xxxx Number=Sing
# design design NOUN NN compound xxxx Number=Sing
# construction construction NOUN NN pobj xxxx Number=Sing
# of of ADP IN prep xx
# team team NOUN NN compound xxxx Number=Sing
# sales sale NOUN NNS pobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# hazids hazid NOUN NNS conj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# materials material NOUN NNS conj xxxx Number=Plur
# for for ADP IN prep xxx
# procedure procedure NOUN NN compound xxxx Number=Sing
# installation installation NOUN NN compound xxxx Number=Sing
# zahra zahra PROPN NNP compound xxxx Number=Sing
# el el PROPN NNP compound xx Number=Sing
# para para PROPN NNP compound xxxx Number=Sing
# tenga tenga PROPN NNP pobj xxxx Number=Sing
# usted uste VERB VBD relcl xxxx Tense=Past|VerbForm=Fin
# est est PROPN NNP punct xxx Number=Sing
# no no DET DT det xx
# passport passport NOUN NN compound xxxx Number=Sing
# details detail NOUN NNS dobj xxxx Number=Plur
# passport passport NOUN NN compound xxxx Number=Sing
# years year NOUN NNS npadvmod xxxx Number=Plur
# four four NUM CD dep xxxx NumType=Card
# to to PART TO prep xx
# , , PUNCT , punct , PunctType=Comm
# control control VERB VB compound xxxx VerbForm=Inf
# compliance compliance NOUN NN compound xxxx Number=Sing
# regulatory regulatory ADJ JJ nsubj xxxx Degree=Pos
# ensure ensure VERB VBP advcl xxxx Tense=Pres|VerbForm=Fin
# to to PART TO aux xx
# prior prior ADV RB amod xxxx
# continue continue VERB VB xcomp xxxx VerbForm=Inf
# may may AUX MD aux xxx VerbForm=Fin
# coordinator coordinator VERB VB ccomp xxxx VerbForm=Inf
# safety safety NOUN NN dobj xxxx Number=Sing
# all all PRON DT dep xxx
# for for ADP IN prep xxx
# management management NOUN NN compound xxxx Number=Sing
# contract contract NOUN NN conj xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# and and CCONJ CC cc xxx ConjType=Cmp
# construction construction NOUN NN compound xxxx Number=Sing
# project project NOUN NN dobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# dry dry ADJ JJ conj xxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# line line NOUN NN dobj xxxx Number=Sing
# main main ADJ JJ amod xxxx Degree=Pos
# with with ADP IN prep xxxx
# assisted assisted ADJ JJ pobj xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# routers router NOUN NNS conj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# anchors anchor NOUN NNS nsubj xxxx Number=Plur
# concrete concrete ADJ JJ amod xxxx Degree=Pos
# on on ADP IN prep xx
# improved improve VERB VBN ROOT xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Orders order NOUN NNS compound Xxxxx Number=Plur
# purchase purchase NOUN NN nsubj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# systems system NOUN NNS compound xxxx Number=Plur
# rail rail NOUN NN conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# city city NOUN NN conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# inventory inventory NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# bathrooms bathroom NOUN NNS conj xxxx Number=Plur
# maintained maintain VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# . . PUNCT . punct . PunctType=Peri
# Saw see VERB VBN nsubj Xxx Aspect=Perf|Tense=Past|VerbForm=Part
# of of ADP IN prep xx
# notices notice NOUN NNS pobj xxxx Number=Plur
# obtained obtain VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# garage garage NOUN NN compound xxxx Number=Sing
# parking parking NOUN NN compound xxxx Number=Sing
# story story NOUN NN compound xxxx Number=Sing
# m. m. NOUN NN compound x. Number=Sing
# Impacts Impacts PROPN NNPS compound Xxxxx Number=Plur
# schedule schedule VERB VBP dobj xxxx Tense=Pres|VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# into into ADP IN conj xxxx
# long long ADJ JJ pobj xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# from from ADP IN prep xxxx
# roads road NOUN NNS nmod xxxx Number=Plur
# temporary temporary ADJ JJ amod xxxx Degree=Pos
# state state NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# manager manager NOUN NN compound xxxx Number=Sing
# business business NOUN NN compound xxxx Number=Sing
# cleaning cleaning NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# years year NOUN NNS conj xxxx Number=Plur
# two two NUM CD nummod xxx NumType=Card
# managed manage VERB VBD pcomp xxxx Tense=Past|VerbForm=Fin
# successfully successfully ADV RB advmod xxxx
# product product NOUN NN nmod xxxx Number=Sing
# final final ADJ JJ amod xxxx Degree=Pos
# present present ADJ JJ amod xxxx Degree=Pos
# subcontractors subcontractor NOUN NNS dobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# engineering engineer VERB VBG conj xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# civil civil ADJ JJ oprd xxxx Degree=Pos
# in in ADP IN prep xx
# resulted result VERB VBD pobj xxxx Tense=Past|VerbForm=Fin
# which which PRON WDT nsubj xxxx
# , , PUNCT , punct , PunctType=Comm
# projects project VERB VBZ advcl xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# construction construction NOUN NN dobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# engineers engineer NOUN NNS conj xxxx Number=Plur
# support support VERB VBP dobj xxxx Tense=Pres|VerbForm=Fin
# ensure ensure VERB VB xcomp xxxx VerbForm=Inf
# to to ADP IN prep xx
# projects project NOUN NNS pobj xxxx Number=Plur
# notable notable ADJ JJ amod xxxx Degree=Pos
# some some PRON DT dobj xxxx
# . . PUNCT . punct . PunctType=Peri
# Concepts concept NOUN NNS nsubj Xxxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# responded respond VERB VBD conj xxxx Tense=Past|VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# products product NOUN NNS conj xxxx Number=Plur
# requested request VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# procurement procurement NOUN NN nsubj xxxx Number=Sing
# regarding regard VERB VBG acl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# managers manager NOUN NNS compound xxxx Number=Plur
# project project NOUN NN compound xxxx Number=Sing
# stair stair NOUN NN compound xxxx Number=Sing
# pedestrians pedestrian NOUN NNS dobj xxxx Number=Plur
# exterior exterior NOUN NN amod xxxx Number=Sing
# on on ADP IN prep xx
# manager manager NOUN NN compound xxxx Number=Sing
# construction construction NOUN NN compound xxxx Number=Sing
# dependents dependent NOUN NNS pobj xxxx Number=Plur
# of of ADP IN prep xx
# each each DET DT det xxxx
# help help NOUN NN pobj xxxx Number=Sing
# can can AUX MD conj xxx VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# flashings flashing NOUN NNS conj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# situation situation NOUN NN nsubj xxxx Number=Sing
# any any PRON DT dobj xxx
# in in ADP IN prep xx
# materials material NOUN NNS nmod xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# meetings meeting NOUN NNS conj xxxx Number=Plur
# contractor contractor NOUN NN compound xxxx Number=Sing
# general general NOUN NN pobj xxxx Number=Sing
# all all ADV RB advmod xxx
# out out ADV RB advmod xxx
# builds build VERB VBZ ccomp xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# l l PROPN NNP compound x Number=Sing
# p. p. NOUN NN compound x. Number=Sing
# Discrepancies Discrepancies PROPN NNP compound Xxxxx Number=Sing
# assembly assembly NOUN NN dobj xxxx Number=Sing
# rf rf AUX IN aux xx
# operated operate VERB VBN ccomp xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# . . PUNCT . punct . PunctType=Peri
# Inspections inspection NOUN NNS nsubj Xxxxx Number=Plur
# required require VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# not not PART RB neg xxx Polarity=Neg
# but but CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# city city NOUN NN compound xxxx Number=Sing
# management management NOUN NN compound xxxx Number=Sing
# schedule schedule NOUN NN conj xxxx Number=Sing
# in in ADP IN prep xx
# skilled skilled ADJ JJ amod xxxx Degree=Pos
# to to ADP IN prep xx
# results result NOUN NNS pobj xxxx Number=Plur
# . . PUNCT . punct . PunctType=Peri
# Counters counter NOUN NNS nsubj Xxxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# databases database VERB VBZ ROOT xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# project project VERB VBP xcomp xxxx Tense=Pres|VerbForm=Fin
# construction construction NOUN NN dobj xxxx Number=Sing
# for for ADP IN prep xxx
# expert expert NOUN NN pobj xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Manager manager NOUN NN compound Xxxxx Number=Sing
# project project NOUN NN nsubj xxxx Number=Sing
# of of ADP IN prep xx
# remodel remodel PROPN NNP compound xxxx Number=Sing
# office office PROPN NNP pobj xxxx Number=Sing
# paced pace VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# fast fast ADJ JJ amod xxxx Degree=Pos
# detail detail NOUN NN dobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# far far ADV RB advmod xxx
# so so SCONJ IN advmod xx
# life life NOUN NN npadvmod xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# managed manage VERB VBN advcl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Bases basis NOUN NNS compound Xxxxx Number=Plur
# daily daily ADV RB advmod xxxx
# adjust adjust VERB VBP ROOT xxxx Tense=Pres|VerbForm=Fin
# to to ADP IN prep xx
# nov nov PROPN NNP compound xxx Number=Sing
# manager manager NOUN NN compound xxxx Number=Sing
# engineering engineering NOUN NN compound xxxx Number=Sing
# energy energy NOUN NN pobj xxxx Number=Sing
# of of ADP IN prep xx
# state state NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# detail detail NOUN NN dobj xxxx Number=Sing
# to to ADP IN prep xx
# down down ADV RB pcomp xxxx
# shut shut PROPN NNP compound xxxx Number=Sing
# platform platform PROPN NNP pobj xxxx Number=Sing
# offshore offshore ADV RB advmod xxxx
# brownfield brownfield PROPN NNP nsubj xxxx Number=Sing
# largest large ADJ JJS advcl xxxx Degree=Sup
# the the PRON DT nsubj xxx Definite=Def|PronType=Art
# to to PART TO aux xx
# responded respond VERB VBN ccomp xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# , , PUNCT , punct , PunctType=Comm
# research research NOUN NN nmod xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# state state NOUN NN nmod xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# member member NOUN NN appos xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Orientation Orientation PROPN NNP nsubj Xxxxx Number=Sing
# arranged arrange VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# . . PUNCT . punct . PunctType=Peri
# Audits audits NOUN NN compound Xxxxx Number=Sing
# construction construction NOUN NN compound xxxx Number=Sing
# kennecott kennecott PROPN NNP compound xxxx Number=Sing
# state state PROPN NNP ROOT xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# safety safety NOUN NN compound xxxx Number=Sing
# site site NOUN NN appos xxxx Number=Sing
# for for ADP IN prep xxx
# jobsite jobsite PROPN NNP pobj xxxx Number=Sing
# as as SCONJ IN mark xx
# worked work VERB VBN advcl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# By by ADP IN prep Xx
# organization organization NOUN NN compound xxxx Number=Sing
# calendar calendar NOUN NN compound xxxx Number=Sing
# day day NOUN NN compound xxx Number=Sing
# business business NOUN NN compound xxxx Number=Sing
# arts art NOUN NNS nsubj xxxx Number=Plur
# of of ADP IN prep xx
# knowledge knowledge NOUN NN pobj xxxx Number=Sing
# advanced advanced ADJ JJ ROOT xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# girder girder NOUN NN compound xxxx Number=Sing
# steel steel NOUN NN compound xxxx Number=Sing
# concrete concrete NOUN NN conj xxxx Number=Sing
# for for ADP IN prep xxx
# buildings building NOUN NNS compound xxxx Number=Plur
# commercial commercial NOUN NN pobj xxxx Number=Sing
# of of ADP IN prep xx
# duties duty NOUN NNS pobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# s s NOUN NN compound x Number=Sing
# nation nation NOUN NN dep xxxx Number=Sing
# the the PRON DT appos xxx Definite=Def|PronType=Art
# through through ADP IN prep xxxx
# profits profit NOUN NNS pobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# prepared prepare VERB VBN conj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Requirements requirement NOUN NNS compound Xxxxx Number=Plur
# site site NOUN NN ROOT xxxx Number=Sing
# all all PRON DT advmod xxx
# , , PUNCT , punct , PunctType=Comm
# action action NOUN NN nsubj xxxx Number=Sing
# of of ADP IN prep xx
# team team NOUN NN pobj xxxx Number=Sing
# of of ADP IN prep xx
# phases phase NOUN NNS pobj xxxx Number=Plur
# all all PRON DT dep xxx
# submitted submit VERB VBN conj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# trucks truck NOUN NNS conj xxxx Number=Plur
# onto onto ADP IN prep xxxx
# orders order NOUN NNS compound xxxx Number=Plur
# change change NOUN NN compound xxxx Number=Sing
# assist assist NOUN NN pobj xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Industry industry NOUN NN nmod Xxxxx Number=Sing
# construction construction NOUN NN nmod xxxx Number=Sing
# energetic energetic ADJ JJ amod xxxx Degree=Pos
# managersummary managersummary ADJ JJ amod xxxx Degree=Pos
# construction construction NOUN NN ROOT xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Responsibilities responsibility NOUN NNS compound Xxxxx Number=Plur
# l l NOUN NN compound x Number=Sing
# int int NOUN NN compound xxx Number=Sing
# contractors contractor NOUN NNS nsubj xxxx Number=Plur
# sub sub VERB VBP ROOT xxx Tense=Pres|VerbForm=Fin
# of of ADP IN prep xx
# record record NOUN NN pobj xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Projects project NOUN NNS nsubj Xxxxx Number=Plur
# out out ADP RP prt xxx
# closed close VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# systematically systematically ADV RB advmod xxxx
# . . PUNCT . punct . PunctType=Peri
# Sector sector NOUN NN nsubj Xxxxx Number=Sing
# private private ADJ JJ amod xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# proposal proposal NOUN NN conj xxxx Number=Sing
# prepare prepare VERB VBP csubj xxxx Tense=Pres|VerbForm=Fin
# technologists technologist NOUN NNS nsubj xxxx Number=Plur
# engineer engineer VERB VBP ccomp xxxx Tense=Pres|VerbForm=Fin
# civil civil ADJ JJ amod xxxx Degree=Pos
# multilingual multilingual ADJ JJ dobj xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# reports report NOUN NNS compound xxxx Number=Plur
# site site NOUN NN compound xxxx Number=Sing
# creation creation NOUN NN compound xxxx Number=Sing
# schedules schedule NOUN NNS compound xxxx Number=Plur
# payments payment NOUN NNS nsubj xxxx Number=Plur
# card card NOUN NN compound xxxx Number=Sing
# entry entry NOUN NN compound xxxx Number=Sing
# data datum NOUN NNS dobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# city city NOUN NN compound xxxx Number=Sing
# name name NOUN NN compound xxxx Number=Sing
# company company NOUN NN appos xxxx Number=Sing
# to to PART TO aux xx
# opportunity opportunity VERB VB advcl xxxx VerbForm=Inf
# the the PRON DT dobj xxx Definite=Def|PronType=Art
# in in ADP IN prep xx
# stores store NOUN NNS pobj xxxx Number=Plur
# five five NUM CD nsubj xxxx NumType=Card
# is be AUX VBZ ccomp xx Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# who who PRON WP nsubj xxx
# owners owner VERB VBZ ccomp xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# institutional institutional ADJ JJ amod xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# studies study NOUN NNS conj xxxx Number=Plur
# assessment assessment NOUN NN compound xxxx Number=Sing
# risk risk NOUN NN compound xxxx Number=Sing
# management management NOUN NN compound xxxx Number=Sing
# property property NOUN NN compound xxxx Number=Sing
# mills mill NOUN NNS dobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# spans span NOUN NNS nsubj xxxx Number=Plur
# single single ADJ JJ amod xxxx Degree=Pos
# new new ADJ JJ amod xxx Degree=Pos
# to to ADP IN prep xx
# drains drain NOUN NNS compound xxxx Number=Plur
# condensation condensation NOUN NN pobj xxxx Number=Sing
# cleaned clean VERB VBN ROOT xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Contractor contractor NOUN NN nsubj Xxxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# preparation preparation NOUN NN conj xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# determined determined ADJ JJ ROOT xxxx Degree=Pos
# . . PUNCT . punct . PunctType=Peri
# Specialists specialist NOUN NNS nsubj Xxxxx Number=Plur
# teaches teach VERB VBZ ROOT xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# that that DET DT det xxxx Number=Sing|PronType=Dem
# mechanism mechanism NOUN NN compound xxxx Number=Sing
# analysis analysis NOUN NN dobj xxxx Number=Sing
# structural structural ADJ JJ amod xxxx Degree=Pos
# of of ADP IN prep xx
# cost cost NOUN NN pobj xxxx Number=Sing
# in in ADP IN prep xx
# back back ADV RB pcomp xxxx
# us we PRON PRP pobj xx Case=Acc|Number=Plur|Person=1|PronType=Prs
# , , PUNCT , punct , PunctType=Comm
# architects architect VERB VBZ conj xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# landscape landscape NOUN NN dobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# platforms platform NOUN NNS conj xxxx Number=Plur
# offshore offshore ADV RB advmod xxxx
# , , PUNCT , punct , PunctType=Comm
# maryland maryland VERB VBP conj xxxx Tense=Pres|VerbForm=Fin
# in in ADP IN prep xx
# tasks task NOUN NNS pobj xxxx Number=Plur
# complete complete ADJ JJ conj xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# line line NOUN NN conj xxxx Number=Sing
# on on ADP IN prep xx
# ensure ensure NOUN NN pobj xxxx Number=Sing
# to to ADP IN prep xx
# tornados tornado NOUN NNS pobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# design design NOUN NN compound xxxx Number=Sing
# contractor contractor NOUN NN compound xxxx Number=Sing
# general general NOUN NN conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# sincerely sincerely ADV RB advmod xxxx
# . . PUNCT . punct . PunctType=Peri
# Maintenance maintenance NOUN NN nsubj Xxxxx Number=Sing
# requiring require VERB VBG acl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# areas area NOUN NNS dobj xxxx Number=Plur
# many many ADJ JJ nsubj xxxx Degree=Pos
# see see VERB VBP ROOT xxx Tense=Pres|VerbForm=Fin
# to to ADP IN prep xx
# advice advice NOUN NN compound xxxx Number=Sing
# product product NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# employer employer NOUN NN appos xxxx Number=Sing
# by by ADP IN prep xx
# commended commend VERB VBN pobj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Roads road NOUN NNS nsubj Xxxxx Number=Plur
# temporary temporary ADJ JJ amod xxxx Degree=Pos
# and and CCONJ CC cc xxx ConjType=Cmp
# equipment equipment NOUN NN conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# plans plan NOUN NNS nsubj xxxx Number=Plur
# coordinated coordinate VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# problems problem NOUN NNS conj xxxx Number=Plur
# major major ADJ JJ amod xxxx Degree=Pos
# adco adco ADJ JJ amod xxxx Degree=Pos
# operations operation NOUN NNS compound xxxx Number=Plur
# warehouse warehouse NOUN NN dobj xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# created create VERB VBN dobj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Cert cert NOUN NN compound Xxxx Number=Sing
# waste waste NOUN NN npadvmod xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# workers worker NOUN NNS nsubj xxxx Number=Plur
# observed observe VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# designs design NOUN NNS dobj xxxx Number=Plur
# proposed propose VERB VBD acl xxxx Tense=Past|VerbForm=Fin
# investigated investigate VERB VBN xcomp xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# floors floor NOUN NNS conj xxxx Number=Plur
# hardwood hardwood PROPN NNP conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# project project NOUN NN conj xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Shift shift VERB VB ROOT Xxxxx VerbForm=Inf
# and and CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# civil civil ADJ JJ nsubj xxxx Degree=Pos
# motivated motivate VERB VBD conj xxxx Tense=Past|VerbForm=Fin
# highly highly ADV RB advmod xxxx
# . . PUNCT . punct . PunctType=Peri
# Gains gain NOUN NNS ROOT Xxxxx Number=Plur
# great great ADJ JJ amod xxxx Degree=Pos
# with with ADP IN prep xxxx
# day day NOUN NN pobj xxx Number=Sing
# provided provide VERB VBN acl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Team team NOUN NN ROOT Xxxx Number=Sing
# of of ADP IN prep xx
# stakeholders stakeholder NOUN NNS pobj xxxx Number=Plur
# including include VERB VBG prep xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# operations operation NOUN NNS compound xxxx Number=Plur
# subcontractor subcontractor NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# accidents accident NOUN NNS conj xxxx Number=Plur
# of of ADP IN prep xx
# levels level NOUN NNS compound xxxx Number=Plur
# stock stock NOUN NN compound xxxx Number=Sing
# procuring procure VERB VBG compound xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# procure procure NOUN NN pobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# turbine turbine VERB VB acl xxxx VerbForm=Inf
# wind wind NOUN NN dobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# professional professional ADJ JJ conj xxxx Degree=Pos
# of of ADP IN prep xx
# mutual mutual ADJ JJ pobj xxxx Degree=Pos
# for for ADP IN prep xxx
# signature signature NOUN NN pobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# audit audit NOUN NN compound xxxx Number=Sing
# safety safety NOUN NN conj xxxx Number=Sing
# our our PRON PRP$ poss xxx Number=Plur|Person=1|Poss=Yes|PronType=Prs
# , , PUNCT , punct , PunctType=Comm
# arapahoe arapahoe ADJ JJ conj xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# management management NOUN NN compound xxxx Number=Sing
# time time NOUN NN appos xxxx Number=Sing
# of of ADP IN prep xx
# aspects aspect NOUN NNS pobj xxxx Number=Plur
# all all PRON DT advmod xxx
# for for ADP IN prep xxx
# data datum NOUN NNS pobj xxxx Number=Plur
# autocad autocad ADV RB advmod xxxx
# , , PUNCT , punct , PunctType=Comm
# legal legal ADJ JJ amod xxxx Degree=Pos
# of of ADP IN prep xx
# bachelor bachelor NOUN NN compound xxxx Number=Sing
# preservation preservation NOUN NN nmod xxxx Number=Sing
# historic historic PROPN NNP compound xxxx Number=Sing
# institute institute PROPN NNP nmod xxxx Number=Sing
# technical technical ADJ JJ amod xxxx Degree=Pos
# providing providing NOUN NN pobj xxxx Number=Sing
# by by ADP IN prep xx
# market market NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# leasingdesk leasingdesk PROPN NNP appos xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# presentations presentation NOUN NNS compound xxxx Number=Plur
# project project NOUN NN appos xxxx Number=Sing
# monitored monitor VERB VBN acl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Satisfaction satisfaction NOUN NN compound Xxxxx Number=Sing
# customer customer NOUN NN nsubj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# strategy strategy NOUN NN nmod xxxx Number=Sing
# effective effective ADJ JJ amod xxxx Degree=Pos
# cost cost NOUN NN compound xxxx Number=Sing
# job job NOUN NN appos xxx Number=Sing
# for for ADP IN prep xxx
# equipment equipment NOUN NN compound xxxx Number=Sing
# copying copy VERB VBG pobj xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# other other ADJ JJ amod xxxx Degree=Pos
# any any PRON DT nmod xxx
# and and CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# project project NOUN NN appos xxxx Number=Sing
# of of ADP IN prep xx
# safety safety NOUN NN pobj xxxx Number=Sing
# federal federal ADJ JJ amod xxxx Degree=Pos
# including include VERB VBG prep xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# materials material NOUN NNS pobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# estate estate NOUN NN compound xxxx Number=Sing
# real real NOUN NN conj xxxx Number=Sing
# of of ADP IN prep xx
# operations operation NOUN NNS pobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# subcontractors subcontractor NOUN NNS compound xxxx Number=Plur
# scheduling scheduling NOUN NN compound xxxx Number=Sing
# planning planning NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# discuss discuss NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# completion completion NOUN NN conj xxxx Number=Sing
# to to PART TO aux xx
# guidance guidance NOUN NN relcl xxxx Number=Sing
# provided provide VERB VBN ROOT xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Completion completion NOUN NN nsubj Xxxxx Number=Sing
# to to PART TO aux xx
# staff staff VERB VB acl xxxx VerbForm=Inf
# support support NOUN NN dobj xxxx Number=Sing
# to to ADP IN prep xx
# parties party NOUN NNS pobj xxxx Number=Plur
# all all PRON DT appos xxx
# ensuring ensure VERB VBG ROOT xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Office office NOUN NN nsubj Xxxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# logistics logistic NOUN NNS conj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# schedules schedule NOUN NNS conj xxxx Number=Plur
# revamped revamp VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# personally personally ADV RB advmod xxxx
# . . PUNCT . punct . PunctType=Peri
# Representatives representative NOUN NNS poss Xxxxx Number=Plur
# s s PART POS case x
# master master NOUN NN nsubj xxxx Number=Sing
# with with ADP IN prep xxxx
# daily daily ADJ JJ amod xxxx Degree=Pos
# managed manage VERB VBN pobj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# , , PUNCT , punct , PunctType=Comm
# committed commit VERB VBN ROOT xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Schedule schedule NOUN NN nsubj Xxxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# price price NOUN NN compound xxxx Number=Sing
# rap rap NOUN NN compound xxx Number=Sing
# rip rip NOUN NN appos xxx Number=Sing
# for for ADP IN prep xxx
# drawings drawing NOUN NNS pobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# plans plan VERB VBZ advcl xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# management management NOUN NN compound xxxx Number=Sing
# crisis crisis NOUN NN dobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# calls call VERB VBZ ROOT xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# incoming income VERB VBG xcomp xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# all all DET DT det xxx
# maintain maintain NOUN NN oprd xxxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Market market NOUN NN ROOT Xxxxx Number=Sing
# the the PRON DT dobj xxx Definite=Def|PronType=Art
# and and CCONJ CC cc xxx ConjType=Cmp
# create create VERB VB conj xxxx VerbForm=Inf
# to to ADP IN prep xx
# needing need VERB VBG pcomp xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# work work NOUN NN dobj xxxx Number=Sing
# final final ADJ JJ amod xxxx Degree=Pos
# of of ADP IN prep xx
# tracking tracking NOUN NN pobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# dollars dollar NOUN NNS compound xxxx Number=Plur
# million million NUM CD conj xxxx NumType=Card
# of of ADP IN prep xx
# construction construction NOUN NN nmod xxxx Number=Sing
# national national ADJ JJ nmod xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# saws saw NOUN NNS nmod xxxx Number=Plur
# pruning prune VERB VBG acl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# trim trim ADJ JJ conj xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# systems system NOUN NNS compound xxxx Number=Plur
# information information NOUN NN nmod xxxx Number=Sing
# much much ADJ JJ amod xxxx Degree=Pos
# department department NOUN NN pobj xxxx Number=Sing
# the the PRON DT nmod xxx Definite=Def|PronType=Art
# of of ADP IN prep xx
# management management NOUN NN compound xxxx Number=Sing
# facilities facility NOUN NNS pobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# cbi cbi PROPN NNP npadvmod xxx Number=Sing
# . . PUNCT . punct . PunctType=Peri
# Settings setting NOUN NNS compound Xxxxx Number=Plur
# system system NOUN NN nsubj xxxx Number=Sing
# to to ADP IN prep xx
# ability ability NOUN NN compound xxxx Number=Sing
# packages package NOUN NNS pobj xxxx Number=Plur
# welcome welcome VERB VBP ccomp xxxx Tense=Pres|VerbForm=Fin
# conference conference NOUN NN compound xxxx Number=Sing
# organizing organizing NOUN NN dobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# facilities facility NOUN NNS compound xxxx Number=Plur
# director director NOUN NN nsubj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# estimator estimator NOUN NN conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# slabs slab NOUN NNS compound xxxx Number=Plur
# concrete concrete NOUN NN appos xxxx Number=Sing
# for for ADP IN prep xxx
# responsible responsible ADJ JJ pobj xxxx Degree=Pos
# all all PRON DT appos xxx
# for for ADP IN prep xxx
# office office NOUN NN pobj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# time time NOUN NN conj xxxx Number=Sing
# of of ADP IN prep xx
# items item NOUN NNS pobj xxxx Number=Plur
# unidentified unidentified ADJ JJ amod xxxx Degree=Pos
# or or CCONJ CC cc xx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# imageready imageready ADJ JJ conj xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# finish finish NOUN NN csubj xxxx Number=Sing
# for for ADP IN prep xxx
# merchandise merchandise NOUN NN compound xxxx Number=Sing
# return return NOUN NN pobj xxxx Number=Sing
# in in ADP IN prep xx
# involved involve VERB VBN pobj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# was be AUX VBD ROOT xxx Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# which which PRON WDT nsubj xxxx
# , , PUNCT , punct , PunctType=Comm
# sheetrock sheetrock NOUN NN nsubj xxxx Number=Sing
# hanging hang VERB VBG advcl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# , , PUNCT , punct , PunctType=Comm
# . . PUNCT . punct . PunctType=Peri
# Pipe pipe NOUN NN compound Xxxx Number=Sing
# facility facility NOUN NN nsubj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# coordination coordination NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# design design NOUN NN compound xxxx Number=Sing
# oversaw oversaw NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# interior interior NOUN NN conj xxxx Number=Sing
# installed instal VERB VBN ROOT xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Personnel Personnel NOUN NNS compound Xxxxx Number=Plur
# construction construction NOUN NN nmod xxxx Number=Sing
# commercial commercial ADJ JJ amod xxxx Degree=Pos
# extensive extensive ADJ JJ amod xxxx Degree=Pos
# utilize utilize NOUN NN ROOT xxxx Number=Sing
# can can AUX MD aux xxx VerbForm=Fin
# , , PUNCT , punct , PunctType=Comm
# steel steel NOUN NN compound xxxx Number=Sing
# carbon carbon NOUN NN nsubj xxxx Number=Sing
# activated activate VERB VBN acl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# re re ADP IN prep xx
# main main ADJ JJ amod xxxx Degree=Pos
# engineer engineer NOUN NN pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# submittals submittal NOUN NNS conj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# legal legal ADJ JJ conj xxxx Degree=Pos
# the the PRON DT punct xxx Definite=Def|PronType=Art
# in in ADP IN prep xx
# years year NOUN NNS pobj xxxx Number=Plur
# two two NUM CD nummod xxx NumType=Card
# installation installation NOUN NN appos xxxx Number=Sing
# for for ADP IN prep xxx
# recommendations recommendation NOUN NNS pobj xxxx Number=Plur
# utilized utilize VERB VBN acl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# Loads load NOUN NNS nsubj Xxxxx Number=Plur
# ...
# , , PUNCT , punct , PunctType=Comm
# procurement procurement NOUN NN compound xxxx Number=Sing
# buying buying NOUN NN compound xxxx Number=Sing
# skills skill NOUN NNS appos xxxx Number=Plur
# writing write VERB VBG acl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# by by ADP IN prep xx
# validated validate VERB VBN pobj xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# B b NOUN NN compound X Number=Sing
# my my PRON PRP$ ROOT xx Number=Sing|Person=1|Poss=Yes|PronType=Prs
# . . PUNCT . punct . PunctType=Peri
# Deadlines deadline NOUN NNS nsubj Xxxxx Number=Plur
# make make VERB VBP ROOT xxxx Tense=Pres|VerbForm=Fin
# help help NOUN NN dobj xxxx Number=Sing
# to to ADP IN prep xx
# dimensions dimension NOUN NNS pobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# mains main NOUN NNS compound xxxx Number=Plur
# water water NOUN NN conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# dollars dollar VERB VBZ compound xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# million million NUM CD dobj xxxx NumType=Card
# of of ADP IN prep xx
# deliveries delivery NOUN NNS pobj xxxx Number=Plur
# and and CCONJ CC cc xxx ConjType=Cmp
# stamina stamina PROPN NNP conj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# implement implement NOUN NN conj xxxx Number=Sing
# and and CCONJ CC cc xxx ConjType=Cmp
# facilities facility NOUN NNS conj xxxx Number=Plur
# fiber fiber NOUN NN compound xxxx Number=Sing
# communications communication NOUN NNS appos xxxx Number=Plur
# in in ADP IN prep xx
# engineeringcoursework engineeringcoursework PROPN NNP nmod xxxx Number=Sing
# industrial industrial ADJ JJ amod xxxx Degree=Pos
# buildings building NOUN NNS compound xxxx Number=Plur
# commercial commercial ADJ JJ pobj xxxx Degree=Pos
# , , PUNCT , punct , PunctType=Comm
# plans plan VERB VBZ conj xxxx Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# reviews review NOUN NNS compound xxxx Number=Plur
# constructibility constructibility NOUN NN nsubj xxxx Number=Sing
# performed perform VERB VBD ccomp xxxx Tense=Past|VerbForm=Fin
# . . PUNCT . punct . PunctType=Peri
# Chair chair NOUN NN compound Xxxxx Number=Sing
# department department NOUN NN nsubj xxxx Number=Sing
# the the DET DT det xxx Definite=Def|PronType=Art
# build build VERB VBP ROOT xxxx Tense=Pres|VerbForm=Fin
# all all DET DT det xxx
# opening opening NOUN NN compound xxxx Number=Sing
# scheduling scheduling NOUN NN dobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# compliance compliance NOUN NN compound xxxx Number=Sing
# assess assess NOUN NN nsubj xxxx Number=Sing
# to to ADP IN prep xx
# company company NOUN NN pobj xxxx Number=Sing
# current current ADJ JJ amod xxxx Degree=Pos
# to to PART TO aux xx
# designed design VERB VBN acl xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# are be AUX VBP ccomp xxx Mood=Ind|Tense=Pres|VerbForm=Fin
# duties duty NOUN NNS compound xxxx Number=Plur
# group group NOUN NN attr xxxx Number=Sing
# this this PRON DT nsubj xxxx Number=Sing|PronType=Dem
# using use VERB VBG advcl xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# by by ADP IN prep xx
# there there ADV RB pcomp xxxx PronType=Dem
# . . PUNCT . punct . PunctType=Peri
# Contracts contract NOUN NNS nsubj Xxxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# merchandise merchandise NOUN NN compound xxxx Number=Sing
# deliver deliver VERB VBP conj xxxx Tense=Pres|VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# company company NOUN NN conj xxxx Number=Sing
# to to ADP IN prep xx
# materials material NOUN NNS pobj xxxx Number=Plur
# on on ADP IN advmod xx
# and and CCONJ CC cc xxx ConjType=Cmp
# proposals proposal NOUN NNS conj xxxx Number=Plur
# for for ADP IN prep xxx
# project project NOUN NN pobj xxxx Number=Sing
# programprioritized programprioritize VERB VBD acl xxxx Tense=Past|VerbForm=Fin
# ses ses PROPN NNP compound xxx Number=Sing
# bge bge PROPN NNP dobj xxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# cam cam PROPN NNP compound xxx Number=Sing
# ldo ldo PROPN NNP conj xxx Number=Sing
# used use VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# girders girder NOUN NNS compound xxxx Number=Plur
# aashto aashto NOUN NNS dobj xxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# total total ADJ JJ amod xxxx Degree=Pos
# combined combine VERB VBN amod xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# million million NUM CD appos xxxx NumType=Card
# . . PUNCT . punct . PunctType=Peri
# Subcontractors subcontractor NOUN NNS nsubj Xxxxx Number=Plur
# , , PUNCT , punct , PunctType=Comm
# trained train VERB VBD ROOT xxxx Tense=Past|VerbForm=Fin
# . . PUNCT . punct . PunctType=Peri
# Tracking track VERB VBG compound Xxxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# production production NOUN NN dobj xxxx Number=Sing
# of of ADP IN prep xx
# rights right NOUN NNS pobj xxxx Number=Plur
# additional additional ADJ JJ amod xxxx Degree=Pos
# for for ADP IN prep xxx
# accountable accountable ADJ JJ amod xxxx Degree=Pos
# state state NOUN NN pobj xxxx Number=Sing
# with with ADP IN prep xxxx
# working work VERB VBG pcomp xxxx Aspect=Prog|Tense=Pres|VerbForm=Part
# to to ADP IN prep xx
# up up ADP RP prt xx
# projects project NOUN NNS dobj xxxx Number=Plur
# housing housing NOUN NN dobj xxxx Number=Sing
# new new ADJ JJ nsubj xxx Degree=Pos
# of of ADP IN prep xx
# efforts effort NOUN NNS pobj xxxx Number=Plur
# kaizen kaizen VERB VBP ROOT xxxx Tense=Pres|VerbForm=Fin
# the the PRON DT dobj xxx Definite=Def|PronType=Art
# for for ADP IN prep xxx
# days day NOUN NNS pobj xxxx Number=Plur
# number number NOUN NN nsubj xxxx Number=Sing
# managed manage VERB VBD ccomp xxxx Tense=Past|VerbForm=Fin
# . . PUNCT . punct . PunctType=Peri
# Day day NOUN NN npadvmod Xxx Number=Sing
# every every PRON DT nsubj xxxx
# of of ADP IN prep xx
# all all PRON DT pobj xxx
# managed manage VERB VBN amod xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# and and CCONJ CC cc xxx ConjType=Cmp
# texas texas PROPN NNP compound xxxx Number=Sing
# southeast southeast PROPN NNP compound xxxx Number=Sing
# manager manager NOUN NN conj xxxx Number=Sing
# construction construction NOUN NN nsubj xxxx Number=Sing
# provided provide VERB VBD ccomp xxxx Tense=Past|VerbForm=Fin
# and and CCONJ CC cc xxx ConjType=Cmp
# laws law NOUN NNS compound xxxx Number=Plur
# state state NOUN NN nmod xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# city city NOUN NN compound xxxx Number=Sing
# university university NOUN NN compound xxxx Number=Sing
# manager manager NOUN NN compound xxxx Number=Sing
# warehouse warehouse NOUN NN conj xxxx Number=Sing
# in in ADP IN prep xx
# lab lab NOUN NN nmod xxx Number=Sing
# assistant assistant NOUN NN compound xxxx Number=Sing
# lending lending NOUN NN compound xxxx Number=Sing
# senior senior ADJ JJ pobj xxxx Degree=Pos
# of of ADP IN prep xx
# standards standard NOUN NNS pobj xxxx Number=Plur
# quality quality NOUN NN appos xxxx Number=Sing
# improve improve VERB VB advcl xxxx VerbForm=Inf
# to to ADP IN prep xx
# august august PROPN NNP compound xxxx Number=Sing
# coordinator coordinator NOUN NN compound xxxx Number=Sing
# safety safety NOUN NN pobj xxxx Number=Sing
# a a PRON DT dobj x Definite=Ind|PronType=Art
# with with ADP IN prep xxxx
# building building NOUN NN compound xxxx Number=Sing
# relationship relationship NOUN NN nsubj xxxx Number=Sing
# extend extend VERB VB pobj xxxx VerbForm=Inf
# and and CCONJ CC cc xxx ConjType=Cmp
# , , PUNCT , punct , PunctType=Comm
# english english PROPN NNP pobj xxxx Number=Sing
# , , PUNCT , punct , PunctType=Comm
# plans plan NOUN NNS nsubj xxxx Number=Plur
# coordinated coordinate VERB VBN ROOT xxxx Aspect=Perf|Tense=Past|VerbForm=Part
# . . PUNCT . punct . PunctType=Peri
# /home/fossa/deb/tests/capstone/venv/lib/python3.7/site-packages/spacy/displacy/__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="72b0b0af31684e928cc7fb3312c3f1bd-0" class="displacy" width="5825" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Laws</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">applicable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">overcame</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">welding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">meetings,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">vendors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">aerial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">knowledge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">gain</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">to,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">project</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">managed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">surveyors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">education</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">extensive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">systems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">keeping</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">products</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">university</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
splittext = cap_sent.split(".")
for x in range(5, len(splittext), random.randint(5, 8)):
    splittext[x] = "\n"+"\t"+splittext[x].lstrip()
text = ".".join(splittext)
text = f'\t'+text
print(text)
# Out:
# 	Laws applicable many overcame we and welding with meetings, vendors and aerial of knowledge gain to, project the managed surveyors and education extensive systems keeping and products of university state, city, eia, design. Weather and function to. Equipment and monitored contracts negotiating and development project with compliance in ksu via hazards all for programs scada, used effectively to surveyors quantity item specific suggesting by profit increased and faxes receiving and supervise responsibilities. Station fueling gas and site job current to responses written excellent skills my serve to adherence ensure to aptitude mathematical and platforms media social and, volume traffic the with tasked official reporting expense supply and codes safety construction oversee to, of reduction after state, support management project the managed all trained and moved and supervision direct professional exercise field construction store the in expert suite office, pa. Scheduling project road eldams, strategy and developed were documents loan, s.
# 	Manner timely in alert must insurance, topsides whj bh total for responsible. Skills maintenance operation equipment or new framed and materials and installed properly purchases for procedures developed. Levels high education. Specifications approved the of implementation pavement the for operation, supervision subcontractor and, delivery commodity radioactive, installing tools power, operator pads of completion job and rail light billion. Ee dragados en iniciales favor por menor delito un incluir puede proceso del escrito por sellado. Tasks complex through weekly conducted march. Inspectors qc qa a ensure to materials and security individuals and contractors all for system tracking production power astoria for location regional project history work pavement rigid and, receipts cash petty office ms, incomplete is safety construction worksite to january engineer geotechnical.
# 	Gravel and tools prototype and private and outreach maximize and standards operational and surveys area madison greater for arrangements travel to plans interpret and contract the through following, contractors, policy company that ensure to october estimator to responsible and mixed and one and improvements adventureland, locate. Engineers and invoices vendor, tasks keep and communication strong demonstrated. Sites project functional, city pad final during warehouse the led hospital orthopedic the of out print design construction of team sales, hazids, materials for procedure installation zahra el para tenga usted est no passport details passport years four to, control compliance regulatory ensure to prior continue may coordinator safety all for management contract the and construction project and dry, line main with assisted and routers, anchors concrete on improved. Orders purchase, systems rail, city, inventory and bathrooms maintained. Saw of notices obtained garage parking story m. Impacts schedule and into long, from roads temporary state, manager business cleaning and years two managed successfully product final present subcontractors and engineering civil in resulted which, projects construction and engineers support ensure to projects notable some. Concepts and responded and products requested and procurement regarding managers project stair pedestrians exterior on manager construction dependents of each help can and flashings, situation any in materials and meetings contractor general all out builds l p.
# 	Discrepancies assembly rf operated. . Inspections required not but, city management schedule in skilled to results. Counters, databases project construction for expert. Manager project of remodel office paced fast detail and far so life the managed. Bases daily adjust to nov manager engineering energy of state, detail to down shut platform offshore brownfield largest the to responded, research, state, member. Orientation arranged.
# 	Audits construction kennecott state, safety site for jobsite as worked. By organization calendar day business arts of knowledge advanced and girder steel concrete for buildings commercial of duties, s nation the through profits and prepared. Requirements site all, action of team of phases all submitted and trucks onto orders change assist. Industry construction energetic managersummary construction. Responsibilities l int contractors sub of record. Projects out closed systematically. Sector private and proposal prepare technologists engineer civil multilingual, reports site creation schedules payments card entry data, city name company to opportunity the in stores five is who owners institutional and studies assessment risk management property mills, spans single new to drains condensation cleaned.
# 	Contractor and preparation the determined. Specialists teaches that mechanism analysis structural of cost in back us, architects landscape and platforms offshore, maryland in tasks complete and line on ensure to tornados and design contractor general, sincerely. Maintenance requiring areas many see to advice product, employer by commended. Roads temporary and equipment, plans coordinated and problems major adco operations warehouse the created. Cert waste, workers observed designs proposed investigated and floors hardwood and project. Shift and, civil motivated highly. Gains great with day provided.
# 	Team of stakeholders including operations subcontractor, accidents of levels stock procuring procure and turbine wind and professional of mutual for signature and audit safety our, arapahoe, management time of aspects all for data autocad, legal of bachelor preservation historic institute technical providing by market, leasingdesk, presentations project monitored. Satisfaction customer, strategy effective cost job for equipment copying other any and, project of safety federal including materials, estate real of operations and subcontractors scheduling planning and discuss and completion to guidance provided. Completion to staff support to parties all ensuring. Office, logistics and schedules revamped personally. Representatives s master with daily managed, committed. Schedule, price rap rip for drawings and plans management crisis, calls incoming all maintain. Market the and create to needing work final of tracking and dollars million of construction national, saws pruning and trim, systems information much department the of management facilities, cbi.
# 	Settings system to ability packages welcome conference organizing and, facilities director, estimator, slabs concrete for responsible all for office and time of items unidentified or, imageready, finish for merchandise return in involved was which, sheetrock hanging, . Pipe facility and coordination and design oversaw and interior installed. Personnel construction commercial extensive utilize can, steel carbon activated re main engineer, submittals, legal the in years two installation for recommendations utilized. Loads work good languages osha telecommunications technical and layout, accounting new for system flow cash preparing reports direct included duties administrative, conservation energy, windows and exposures these over accomplishments p. U the through, suppliers, city name company your agency the for office corporate and ability keen. Projects for panels stone cast pre site the developed the in choice thebest being parts fitted and mechanical of release facilitating, design of scope project housing and capital working. Code surpassing consistently in engineer sales annual, reliability and rice, resolution conflict leadership, calipers as events networking, estado, materials of automation scada, design website the.
# 	Management construction post and functions accounting, consultants, foot s. Supervisor, oriented customer regulations and arts of oversight providing while plans, facilities wireless. Met. A in working hard and retaining place one bridges aashto of management relations student each of management resource and architects landscape and crew working. Personnel of terrain site years in methods construction proposal change generated specifications, foundations new of completion of member team a. Pcor requests order change proposed for assistance provides assistant executive leader strategic develop state, packaging. Personnel and observe state, machines fueling gas, plans floor ground new attract to correctly and restaurant and debris move were projects sites and effectiveness cost provide.
# 	Route and opportunities expand to ability the managed state ny, procurement buying skills writing by validated. B my. Deadlines make help to dimensions and mains water, dollars million of deliveries and stamina, implement and facilities fiber communications in engineeringcoursework industrial buildings commercial, plans reviews constructibility performed. Chair department the build all opening scheduling, compliance assess to company current to designed are duties group this using by there. Contracts, merchandise deliver and company to materials on and proposals for project programprioritized ses bge, cam ldo used girders aashto, total combined million. Subcontractors, trained. Tracking production of rights additional for accountable state with working to up projects housing new of efforts kaizen the for days number managed.
# 	Day every of all managed and texas southeast manager construction provided and laws state, city university manager warehouse in lab assistant lending senior of standards quality improve to august coordinator safety a with building relationship extend and, english, plans coordinated.

# %%
import language_tool_python
tool = language_tool_python.LanguageTool('en-US')
checked_text = tool.correct(text)
print(checked_text)
# Out:
# Develop helped. Deadlines meet to weeks from reports task field, flow dirt, filing phones answering, pricing preliminary and significant delivered reports monthly, marketing, pipelines, weatherproofing connector Andrew professional safety OSHA following. Projects avoid. Of reports, carpenter and concrete and erected being were computers personal, designs the for working. A to, school welding of point single and, individual in m to related issues all mopped and chair co.
# 	Remodeled and cost bid all conducted. Specifications project of scopes, create. Results with employment and orders change evaluated. Vault the of CY, supervised. Up. Improvements tenant and appliances kitchen, XP office versatile summary inspector professional construction solve to December. Industry construction new obtained garage and communication daily the in English, efficiency team operations, manager lab and project ms, flash using effectively to audits construction manager summary construction, managerial delivering success effective skills.
# 	A respect con record to accuracy, excavation of end with consistent were systems computer family or develop to and development residential, managing in proactive the in years solving problem and, lookup vise filing Simulink Matlab OSX mac Linux, events sales leasing. Months eight of types various with rapport establish entries ledger general building services and demeanor professional and meetings contractor general with website commerce of preparation budget efficient effective cost and permits with conferences team time and budgeting project the on go z e and water land and assembly shop reviewed. Designations rejected and square million of profitability and receive. Specifications interpreted containers product final and load lifts major with work that any identified. Team meet to order in assist conditions weather and orientation safety refresher manager construction post leaks reducing while course leadership, lines flow, project construction appropriate developmentally implemented include functions resources human relations media some utilized project this, truck concrete inspecting, Pasco limited not to response emergency, estimates and staff support administrative, managing included that task complete to containers packed. Licenses current and area multi, ICL at personnel quality determine to in part as saved. Stakeholders and acquisition hospital methods construction capital and expenses track in projects civil metro s carrier the in participated assignments special ICC and time satisfactory for utilize effectively by cleared are you if demo of progress reviewing, driven performance the among lines transmission steel structural performed we people calling from thinking critical resolve and construction to.
# 	Shipping and quality, Rockwell, doors install to contractors sub associated activities savings annual. Site, designed was project all with student of informed is office Microsoft, to responding and preparation other and cleanliness maintain to July engineer, inventory monitored conducted. Considerations environmental maintenance performed. Inspector construction, innovation, delays construction building, techniques compaction, two approved and plans marketing b a by building, Memphis, tech ITT ISS engineering chemical for recommendations promotional arranging and questions any has who is a member. Year of construction new framed also but, contracts all conducted. Embargo, construction managing practices fiber new briefed. Vehicles to have they sure make, vista shield Gary, returns, outlook, plumbing, nicer trainer all managed leader management environmental potential their on owner each at plan.
# , SWR, refining, management site governing mandates compliance and, certificate chapter student story and efficiencies,, management inventory skills persuasion and work their fit, maintain. Loads work trim, managed effectively. Project in years for attendance perfect the of fireproofing on analysis specifications, excel Microsoft Dreamweaver adobe, scope the involving activities construction senior for contact of completion project specific promoted. Properly, requirements safety site on based updates progress project construction motivated self, agreement term long, legal, projects of safety formed newly to drawings contract for staking and, letters, leaks roof, plans reading blueprint regulations and detail providing with daily into steel reinforcing for accountable,, group overall the assisted. Side east in bonus a to January to actions corrective permanent make would I hope i. Dates deadlines financial annual, forms three observed work processed vendors with closely worked. Downgrades or renovation major and analytical strong and, strategy evolution team and centers fitness maintained is environment paced fast in adult eastern of bachelor, systems operating the spearheaded.
# 	You, office Microsoft relations community effecting by set site governing mandates system electronics and wrote. Schedules construction renovation interior for responsible. Specifications the in step multi a taking inventory, components worn replaced. Environment organized and regulations and architects with along get to January scheduler corridor. Homes residential, it enjoys i accomplishments. Future my during. Situations emergency medical academic integrated and permits pole.
# 	Projects various in resulting facility naval, business and contractors general and salaries employee development relationship, alternatives construction beys estimator, electrical inspected i, to resourcefulness and archiving and services and,, saws power electrical and maintenance, research excellent. Projects new all to adherence or, delivery time on focused solutions abatement animal and platform activities school airborne army, regulations safety. P experience guidelines authority discretionary using. Piping mechanical an in standards codes safety monthly, size project kept and strategy planned preemptively spaces office inter handling in skills through k new developed. Completion after release retain age in assist. Management and implementation concept, support technical relations customer all conducted and specifications site implemented successfully power electrical for allowed that organization the within and, subcontractors, ceramic, workers communications s nation the, assembly line on audits external and plants power, administration contract upcoming potential up runner award year a LED. Dm the on effort and was steel structural environmental municipalities and s p hombre.
# 	Environment work of volume traffic. Parks Cincinnati the for work writing, subcontractors with inspections monitored. Schedule, key span by person signal and pipe, concrete and succeed desire strong focused org. Schedules ahead plan to contractors various with communicated. Regulations and beginning work ability. Projects construction complete. Abilities service customer performed.
# 	Damages or, lines guide and trim included responsibilities. Personnel lead to services and budgets and budgeting, bi, manager assistant officer loan new all reviewed purchasing of university engineering and directed, manager safety occupational approved and code for specifications approved the in are qualifications. Approach skills communication excellent word Microsoft, reading. Safety, environments team an as. Standards industry other and customers a dozen one de Fuchs salary Trafalgar para Audi necessity is vitae curriculum core hollow steel of part big was work false of associates staff than more summary estimate cost and owners business many as gouge a compressors recycle. S tribe Ute mountain thunder big from codes building relationship built as projects construction for engineer project, to strips overlapping in proficiency office building obtain to coins examined and blocked. External and, curriculum appropriate the with, starters hard a and reviewed.
# 	Expectations exceed to systems or, equipment heavy maneuvered consciously and time, events special, illustration digital impacts environmental and laborers construction and flashings, administrative of field. Wiring and, rules safety heighten as, paralegal, consultants associated activities construction all inspected. Startup of results outstanding on teams trade union none for education. Areas the with laborer working enjoys and homeowners, management construction monitored. Walks site of grading, scope and systems electrical usually install would duties supervisor operations business, partnerships developed in units residential project savvy tech manager summary site all ensure to carpenters as such structures commercial, curbing, toilets, springs Fe Santa of inspections pre during come I roll this in documents subcontract of quality improve to day that individual facilitated and, development gas live existing relocation all that contract, PowerPoint Microsoft, management each of management facility existing of development assist to attention strong for bay, to solutions environmental municipalities various Wei, coaching, departments and attainment educational on work trim included duties. Deadlines meets work monitor. Specifications and communicated.
# 	Equipment and managers construction various with manager office and signing, station degassing south, painting, supervised and Alabama, relations client CSR, HVAC, HVAC certification QS. Skills management estimating, returns and manage to manage are projects multiple on approach team trained extensively. Investors, Arkansas of execution competent. Members crew site employee developed the of consisting portfolio an assuring. Base employee observed work at village Bonhomme communities housing plus cost and preparation analysis economic for values and sales negotiation contract vendor and,, word, documentation, review, IL, spreadsheets, policies project a created and electrical, ii level national nm, manager training the for, promotions, roofs repaired and needs department with bonded and built as budgets construction. Personnel and agreements, sites job and projects of manifesting include to May that program safety public negotiations project, tools hand driving cochindubai issue field of directors of stages various uses who. Projects of number approximately with, control quality, controls, hiring, development business in people and implemented.
# 	Containers of order change needed as knowledge. Methods accounting complicated prioritize and efficiently and time on hooked as well manager project procure, resale for schedules baseline operational unit nanomaterials' science applied of knowledge highlights. Manager construction and, blueprints project in m t may experience costing job any of construction supported. Trucks flatbed ft. Improvements process turnover and plants production of inspection materials cut, levels stock desired locate smoothly run dry wet grading, keeping record no little very skills organizational for separated and desk front in Muslims about passionate and states united the facilitating. Management personnel site all for concrete and, evaluate. Cells solar maximum ensure to gravel, register cash post coordinated carefully.
# 	Items menu. Houses dorm. Construction project history art, routing, sourcing strategic year for bar to exceed or losses, utilities underground, contractor general all one of specifications to easements, acrobat adobe, conditions field. Motivated, materials construction beys estimator manager project for proposals and teams construction unique and completed was group engineering civil, employees with directly reporting daily formulating, cabinets installed helper welders an in resulted. Schedules, program procurement, degree my by operations to necessary documentations maintain. Sites project functional cross skills' association apartment renovate, platinum, rebar inspected. Chair information product support to engineer, built.
# 	Industry utilities, skills. Installations all check to prove will you. Pieces and, anchors concrete as tools, copy a coma la verifier pedalos Que. Surfaces stone and introduction date to up crop that cracks for b all at projects of delivery coordinate and surveillance electronic strong wpm type for prospecting with employees supervised. A Million. , né, bills with construction oversaw i, consulting, roles project, researching, broadband, asphalt, material of terms favorable achieve to equipment or at worked and monitored. WWW see and days within and, vision arc map microstation and energy or alteration course English either all the of series an as.
# 	Cor d very skills' communication stronger facilitated. Free one select a skill solving problem and invoices vendor e. Issues critical time on inspection final ensure to January,

# %%
import spacy
import pyinflect

nlp = spacy.load("en_core_web_sm")

text = checked_text
doc_dep = nlp(text)
for i in range(len(doc_dep)):
    token = doc_dep[i]
    if token.tag_ in ['VBP', 'VBZ']:
        print(token.text, token.lemma_, token.pos_, token.tag_) 
        text = text.replace(token.text, token._.inflect("VBD"))
print(text)
# Out:
# topsides topside VERB VBZ
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3160/3504814075.py in <module>
#      10     if token.tag_ in ['VBP', 'VBZ']:
#      11         print(token.text, token.lemma_, token.pos_, token.tag_)
# ---> 12         text = text.replace(token.text, token._.inflect("VBD"))
#      13 print(text)
#
# TypeError: replace() argument 2 must be str, not None
